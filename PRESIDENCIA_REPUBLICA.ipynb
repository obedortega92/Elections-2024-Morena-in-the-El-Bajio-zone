# %%
import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.cm as cm

mpl.style.use('ggplot')

print('Matplotlib version: ', mpl.__version__)
# Out:
# Matplotlib version:  3.8.0

# %%
df_pres = pd.read_csv('/content/PRESIDENTE_REPUBLICA.csv')
df_pres.head()
# Out:
#                ESTADOS   1994   2000   2006   2012  PROMEDIO
# 0       AGUASCALIENTES  13.54  10.07  26.39  21.40     17.85
# 1      BAJA CALIFORNIA  11.61  11.21  28.10  31.76     20.67
# 2  BAJA CALIFORNIA SUR  10.26  28.87  47.14  25.48     27.94
# 3             CAMPECHE  25.20  15.46  35.15  27.73     25.89
# 4             COAHUILA  18.88  11.18  27.77  20.24     19.52

# %%
df_pres.set_index('ESTADOS', inplace=True)
df_pres.head()
# Out:
#                       1994   2000   2006   2012  PROMEDIO
# ESTADOS
# AGUASCALIENTES       13.54  10.07  26.39  21.40     17.85
# BAJA CALIFORNIA      11.61  11.21  28.10  31.76     20.67
# BAJA CALIFORNIA SUR  10.26  28.87  47.14  25.48     27.94
# CAMPECHE             25.20  15.46  35.15  27.73     25.89
# COAHUILA             18.88  11.18  27.77  20.24     19.52

# %%
df_presi = df_pres.iloc[:,[-1]]
df_presi.head()
# Out:
#                      PROMEDIO
# ESTADOS
# AGUASCALIENTES          17.85
# BAJA CALIFORNIA         20.67
# BAJA CALIFORNIA SUR     27.94
# CAMPECHE                25.89
# COAHUILA                19.52

# %%
df_presi = df_presi.sort_values(by=['PROMEDIO'], ascending=False)

ax = df_presi.plot(kind='bar', figsize=(12, 8))
plt.xlabel('Estado')
plt.ylabel('Porcentaje de votos')

for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2, p.get_height(), '{:.2f}'  .format(p.get_height()),
            fontsize=7, color='black', ha='center', va='bottom')

plt.show()

# %%
target_states = ['AGUASCALIENTES', 'QUERETARO', 'JALISCO', 'GUANAJUATO', 'MICHOACAN', 'SAN LUIS POTOSI', 'ZACATECAS']

# %%
ax = df_presi.plot(kind='bar', figsize=(12, 8), color='red', legend=False)

for i, bar in enumerate(ax.patches):
    if df_presi.index[i] in target_states:
        bar.set_color('blue')

plt.xlabel('Estado')
plt.ylabel('Porcentaje de votos')

for p in ax.patches:
    ax.text(p.get_x() + p.get_width()/2, p.get_height(), '{:.2f}'  .format(p.get_height()),
            fontsize=7, color='black', ha='center', va='bottom')

plt.savefig('my_plot2.png', dpi=300, bbox_inches='tight')
plt.show()
